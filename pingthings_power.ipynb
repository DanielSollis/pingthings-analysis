# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate

import btrdb
from btrdb.utils import timez
from btrdb.point import StatPoint, RawPoint
from btrdb.stream import Stream, StreamSet

import re
from typing import List, Tuple
from datetime import datetime, timedelta

# %% [markdown]
# ## Connect to the database

# %%
# Connect to the NI4AI brtdb database.
conn = btrdb.connect("api.ni4ai.org:4411", apikey='9897F6A9C400164A6E5DEF0F')

# Print a list of the available collections.
collections = conn.list_collections()
for collection in collections:
    print(collection)
# Out:
# brownout/centex
# brownout/conroe
# brownout/whitesands
# c37
# c37_iowa51_0866cb39
# c37_iowa51_0c697f48
# c37_iowa51_1408d2ac
# c37_iowa51_1b6cffa2
# c37_iowa51_1bf98be2
# c37_iowa51_243a768b
# c37_iowa51_25845c95
# c37_iowa51_268447a4
# c37_iowa51_28b62158
# c37_iowa51_30b95ff1
# c37_iowa51_365a8581
# c37_iowa51_3c04951a
# c37_iowa51_41f27cc6
# c37_iowa51_56ec3f25
# c37_iowa51_57e9d186
# c37_iowa51_68255aaf
# c37_iowa53_039f6f78
# c37_iowa53_0a2b894c
# c37_iowa53_144419db
# c37_iowa53_1a02070f
# c37_iowa53_1a714cf8
# c37_iowa53_2584c47f
# c37_iowa53_2606cd2b
# c37_iowa53_2e3108da
# c37_iowa53_430c8b35
# c37_iowa53_490bd268
# c37_iowa53_4dba7b0f
# c37_iowa53_592e17f7
# c37_iowa53_6054502f
# c37_iowa53_6e661e92
# c37_iowa53_6ec34c36
# c37_iowa53_7cd4b7a5
# c37_iowa54_079143f7
# c37_iowa54_162d968d
# c37_iowa54_207403de
# c37_iowa54_23a62343
# c37_iowa54_241b3ae4
# c37_iowa54_2607c649
# c37_iowa54_26984b92
# c37_iowa54_2e4fa459
# c37_iowa54_3629d9f1
# c37_iowa54_43ea3b93
# c37_iowa54_4542c292
# c37_iowa54_45a6e3ca
# c37_iowa54_4c22b029
# c37_iowa54_589442fd
# c37_iowa54_64f1017f
# c37_iowa54_70b5a315
# c37_pmu1_380704bb
# c37_pmu1_4d658221
# c37_pmu1_55104dc7
# c37_pmu1_78629a0f
# chris/sentinel_test2/bedford
# chris/sentinel_test3/bedford
# chris/sentinel_test3/mclean
# chris/sentinel_test/bedford
# comtrade/event0852
# csiro
# ct/Site0009_F_0000065/960_hz
# derconnect/pmu0
# derived/POW/GridSweep/voltage
# derived/POW/underground/phA_amp
# devgen/group1
# devgen/group2
# events/oscillations/StationA_Line1
# events/oscillations/StationA_Line2
# events/oscillations/StationA_Line3
# events/oscillations/StationA_Line4
# events/oscillations/StationA_Line5
# events/oscillations/StationB_Line1
# events/oscillations/StationB_Line2
# events/oscillations/StationB_Line3
# events/oscillations/StationB_Line4
# events/oscillations/StationC_Line1
# events/oscillations/StationD_Line1
# events/oscillations/StationD_Line2
# events/oscillations/StationD_Line3
# events/oscillations/StationE_Line1
# events/oscillations/StationE_Line2
# events/oscillations/StationF_Line1
# events/oscillations/StationG_Line1
# events/oscillations/StationG_Line2
# events/oscillations/StationG_Line3
# events/oscillations/StationG_Line4
# events/oscillations/StationH_Line1
# events/oscillations/StationI_Line1
# events/oscillations/StationI_Line2
# events/small_signal/site1
# events/small_signal/site2
# events/small_signal/site3
# events/small_signal/site4
# events/switching_A/StationA_Line1
# events/switching_A/StationA_Line2
# events/switching_A/StationA_Line3
# events/switching_A/StationA_Line4
# events/switching_A/StationA_Line5
# events/switching_A/StationB_Line1
# events/switching_A/StationB_Line2
# events/switching_A/StationB_Line3
# events/switching_A/StationB_Line4
# events/switching_A/StationC_Line1
# events/switching_A/StationD_Line1
# events/switching_A/StationD_Line2
# events/switching_A/StationD_Line3
# events/switching_A/StationE_Line1
# events/switching_A/StationE_Line2
# events/switching_A/StationF_Line1
# events/switching_A/StationG_Line1
# events/switching_A/StationG_Line2
# events/switching_A/StationG_Line3
# events/switching_A/StationG_Line4
# events/switching_A/StationH_Line1
# events/switching_A/StationI_Line1
# events/switching_A/StationI_Line2
# events/switching_B/StationA_Line1
# events/switching_B/StationA_Line2
# events/switching_B/StationA_Line3
# events/switching_B/StationA_Line4
# events/switching_B/StationA_Line5
# events/switching_B/StationB_Line1
# events/switching_B/StationB_Line2
# events/switching_B/StationB_Line3
# events/switching_B/StationB_Line4
# events/switching_B/StationC_Line1
# events/switching_B/StationD_Line1
# events/switching_B/StationD_Line2
# events/switching_B/StationD_Line3
# events/switching_B/StationE_Line1
# events/switching_B/StationE_Line2
# events/switching_B/StationF_Line1
# events/switching_B/StationG_Line1
# events/switching_B/StationG_Line2
# events/switching_B/StationG_Line3
# events/switching_B/StationG_Line4
# events/switching_B/StationH_Line1
# events/switching_B/StationI_Line1
# events/switching_B/StationI_Line2
# genergy
# gic/noaa/geomag
# gic/noaa/solarwind
# gic/usgs/geomag/BOU
# gic/usgs/geomag/BRW
# gic/usgs/geomag/BSL
# gic/usgs/geomag/CMO
# gic/usgs/geomag/DED
# gic/usgs/geomag/FRD
# gic/usgs/geomag/FRN
# gic/usgs/geomag/GUA
# gic/usgs/geomag/HON
# gic/usgs/geomag/NEW
# gic/usgs/geomag/SHU
# gic/usgs/geomag/SIT
# gic/usgs/geomag/SJG
# gic/usgs/geomag/TUC
# golden/PMU1
# golden/PMU2
# golden/PMU3
# golden/PMU4
# golden/PMU5
# golden/PMU6
# golden/PMU7
# golden/PMU8
# golden/PMU9
# GridSweep/Alameda/0001
# GridSweep/Alameda/0002
# GridSweep/Alameda/0004
# GridSweep/Alameda/0005
# GridSweep/Alameda/0008
# GridSweep/flexlab
# GridSweep/Hawaii/0010
# GridSweep/Hawaii/0011
# GridSweep/Idaho/0005
# GridSweep/Idaho/0006
# GridSweep/Idaho/0007
# GridSweep/Idaho/0008
# GridSweep/Idaho/0009
# Health/EKG/patient001
# lndunn/miscPMU
# monitoring/generator1
# monitoring/generator2
# monitoring/generator3
# monitoring/generator4
# moodytest/dd96-9c06-5f65-a2f0-fb3c11847782
# ni4ai/baltimore
# ni4ai/bellingham
# ni4ai/bishop_creek
# ni4ai/boca_raton
# ni4ai/longmont
# ni4ai/oakland
# ni4ai/pasadena_md
# ni4ai/portland
# ni4ai/richmond
# ni4ai/scottsdale
# ni4ai/silver_spring
# old/oakland0
# POW/Demo
# POW/EPFL
# powerside
# powerside/PMU1
# powerside/PQ1/PQube 3 / www.powerstandards.com
# POW/GridSweep
# Seismic/US/CA
# simulated/ieee13/611
# simulated/ieee13/632
# simulated/ieee13/633
# simulated/ieee13/634
# simulated/ieee13/645
# simulated/ieee13/646
# simulated/ieee13/650
# simulated/ieee13/652
# simulated/ieee13/670
# simulated/ieee13/671
# simulated/ieee13/675
# simulated/ieee13/680
# simulated/ieee13/684
# simulated/ieee13/692
# simulated/ieee13/Line.632633/632
# simulated/ieee13/Line.632633/633
# simulated/ieee13/Line.632645/632
# simulated/ieee13/Line.632645/645
# simulated/ieee13/Line.632670/632
# simulated/ieee13/Line.632670/670
# simulated/ieee13/Line.645646/645
# simulated/ieee13/Line.645646/646
# simulated/ieee13/Line.650632/632
# simulated/ieee13/Line.650632/rg60
# simulated/ieee13/Line.670671/670
# simulated/ieee13/Line.670671/671
# simulated/ieee13/Line.671680/671
# simulated/ieee13/Line.671680/680
# simulated/ieee13/Line.671684/671
# simulated/ieee13/Line.671684/684
# simulated/ieee13/Line.671692/671
# simulated/ieee13/Line.671692/692
# simulated/ieee13/Line.684611/611
# simulated/ieee13/Line.684611/684
# simulated/ieee13/Line.684652/652
# simulated/ieee13/Line.684652/684
# simulated/ieee13/Line.692675/675
# simulated/ieee13/Line.692675/692
# simulated/ieee13/rg60
# simulated/ieee13/sourcebus
# simulated/ieee13/Transformer.reg1/650
# simulated/ieee13/Transformer.reg1/rg60
# simulated/ieee13/Transformer.reg2/650
# simulated/ieee13/Transformer.reg2/rg60
# simulated/ieee13/Transformer.reg3/650
# simulated/ieee13/Transformer.reg3/rg60
# simulated/ieee13/Transformer.sub/650
# simulated/ieee13/Transformer.sub/sourcebus
# simulated/ieee13/Transformer.xfm1/633
# simulated/ieee13/Transformer.xfm1/634
# staging/vermont
# streaming/vermont
# streaming/zurich
# streaming/zurich_zurich250_0230d90a
# streaming/zurich_zurich250_1d3cf6f2
# streaming/zurich_zurich250_295305fa
# streaming/zurich_zurich250_3de8d251
# streaming/zurich_zurich250_55a4c825
# streaming/zurich_zurich250_55cbdc6f
# streaming/zurich_zurich250_5811b1ab
# streaming/zurich_zurich250_5eab4bd4
# streaming/zurich_zurich250_6be74b3c
# streaming/zurich_zurich250_7366708a
# sunshine/PMU1
# sunshine/PMU2
# sunshine/PMU3
# sunshine/PMU4
# sunshine/PMU5
# sunshine/PMU6
# test
# test/plotter
# texas_pmus/centex
# texas_pmus/conroe
# texas_pmus/whitesands
# texas/site0
# texas/site1
# texas/site2
# texas/site3
# texas/site4
# texas/site5
# texas/site6
# texas/site7
# texas/site8
# texas/site9
# trunctest2/f37e-39e5-5df5-a6d0-2cc01e3d4cf6
# trunctest3/3c90-9690-55c9-a7b3-1879ebc22f51
# trunctest/5472-39d9-5c9a-aa0d-9b6e1723056e
# USGS/GEOMAG/Barrow
# USGS/GEOMAG/Boulder
# USGS/GEOMAG/College
# USGS/GEOMAG/Deadhorse
# USGS/GEOMAG/Fredericksburg
# USGS/GEOMAG/Fresno
# USGS/GEOMAG/Guam
# USGS/GEOMAG/Honolulu
# USGS/GEOMAG/Newport
# USGS/GEOMAG/San_Juan
# USGS/GEOMAG/Shumagin
# USGS/GEOMAG/Sitka
# USGS/GEOMAG/Stennis_Space_Center
# USGS/GEOMAG/Tucson
# v3
# zz/aggregate-demo
# zz/aggregate-demo-long
# zz/bellingham
# zz/bytewaxtest/jl//imbalance/ni4ai>baltimore:cd65f5d48667
# zz/china
# zz/distillates/diff-generator2-generator1
# zz/distillates/diff-generator3-generator1
# zz/distillates/diff-generator4-generator1
# zz/distillates/duplicate-times/monitoring/generator1
# zz/distillates/duplicate-times/monitoring/generator2
# zz/distillates/duplicate-times/monitoring/generator3
# zz/distillates/duplicate-times/monitoring/generator4
# zz/distillates/duplicate-times/ni4ai/bellingham
# zz/distillates/duplicate-times/ni4ai/berkeley
# zz/distillates/duplicate-times/ni4ai/bishop_creek
# zz/distillates/duplicate-times/ni4ai/new_york
# zz/distillates/duplicate-times/ni4ai/oakland
# zz/distillates/duplicate-times/ni4ai/portland
# zz/distillates/duplicate-times/ni4ai/scottsdale
# zz/distillates/duplicate-times/ni4ai/silver_spring
# zz/distillates/freq-events/ni4ai/bellingham
# zz/distillates/freq-events/ni4ai/berkeley
# zz/distillates/freq-events/ni4ai/bishop_creek
# zz/distillates/freq-events/ni4ai/bishop_creek_bishop03_7062b076
# zz/distillates/freq-events/ni4ai/new_york
# zz/distillates/freq-events/ni4ai/new_york_ori01_3078a14a
# zz/distillates/freq-events/ni4ai/oakland_laurel01_791505a7
# zz/distillates/freq-events/ni4ai/portland
# zz/distillates/freq-events/ni4ai/scottsdale
# zz/distillates/freq-events/ni4ai/silver_spring
# zz/distillates/freq-events/ni4ai/weld
# zz/distillates/freq-events/ni4ai/weld2
# zz/distillates/phase-unwrapped/generator1monitoring/generator1
# zz/distillates/phase-unwrapped/generator2monitoring/generator2
# zz/distillates/phase-unwrapped/generator3monitoring/generator3
# zz/distillates/phase-unwrapped/generator4monitoring/generator4
# zz/distillates/POW/Demo
# zz/distillates/POW/Demo_dft
# zz/distillates/POW/Demo_lstsq
# zz/distillates/POW/DemoPOW/Demo
# zz/distillates/POW/DemoPOW/Demo_dft
# zz/distillates/POW/DemoPOW/Demo_lstsq
# zz/distillates/POW/GridSweep_dft
# zz/distillates/POW/GridSweep/flexlab_dft
# zz/distillates/POW/GridSweep/flexlab_lstsq
# zz/distillates/POW/GridSweep_lstsq
# zz/distillates/pow/POW/Demo
# zz/distillates/repeat-values/monitoring/generator1
# zz/distillates/repeat-values/monitoring/generator2
# zz/distillates/repeat-values/monitoring/generator3
# zz/distillates/repeat-values/monitoring/generator4
# zz/distillates/repeat-values/ni4ai/bellingham
# zz/distillates/repeat-values/ni4ai/berkeley
# zz/distillates/repeat-values/ni4ai/bishop_creek
# zz/distillates/repeat-values/ni4ai/bishop_creek_bishop03_4cd239ea
# zz/distillates/repeat-values/ni4ai/new_york
# zz/distillates/repeat-values/ni4ai/new_york_ori01_42fff65f
# zz/distillates/repeat-values/ni4ai/oakland
# zz/distillates/repeat-values/ni4ai/portland
# zz/distillates/repeat-values/ni4ai/scottsdale
# zz/distillates/repeat-values/ni4ai/silver_spring
# zz/distillates/zeros/monitoring/generator1
# zz/distillates/zeros/monitoring/generator2
# zz/distillates/zeros/monitoring/generator3
# zz/distillates/zeros/monitoring/generator4
# zz/insert_profile/10_stream_83
# zz/insert_profile/10_stream_84
# zz/insert_profile/10_stream_85
# zz/insert_profile/10_stream_86
# zz/insert_profile/10_stream_87
# zz/insert_profile/10_stream_88
# zz/insert_profile/10_stream_89
# zz/insert_profile/10_stream_9
# zz/insert_profile/10_stream_90
# zz/insert_profile/10_stream_91
# zz/insert_profile/10_stream_92
# zz/insert_profile/10_stream_93
# zz/insert_profile/10_stream_94
# zz/insert_profile/10_stream_95
# zz/insert_profile/10_stream_96
# zz/insert_profile/10_stream_97
# zz/insert_profile/10_stream_98
# zz/insert_profile/10_stream_99
# zz/insert_profile/stream_2
# zz/insert_profile/stream_3
# zz/insert_profile/stream_4
# zz/insert_profile/stream_5
# zz/ni4ai/bishop_creek_bishop03_003e6306
# zz/ni4ai/bishop_creek_bishop03_005d2928
# zz/ni4ai/bishop_creek_bishop03_035ca80d
# zz/ni4ai/bishop_creek_bishop03_03cc44bf
# zz/ni4ai/bishop_creek_bishop03_3332aafe
# zz/ni4ai/bishop_creek_bishop03_346e5f29
# zz/ni4ai/bishop_creek_bishop03_3aae3e3e
# zz/ni4ai/bishop_creek_bishop03_3fba2470
# zz/ni4ai/bishop_creek_bishop03_479a2bf9
# zz/ni4ai/bishop_creek_bishop03_4b7fafc3
# zz/ni4ai/bishop_creek_bishop03_4cd239ea
# zz/ni4ai/bishop_creek_bishop03_4d4f278a
# zz/ni4ai/bishop_creek_bishop03_685f3257
# zz/ni4ai/bishop_creek_bishop03_6c443faf
# zz/ni4ai/bishop_creek_bishop03_7062b076
# zz/ni4ai/bishop_creek_bishop03_7539a201
# zz/ni4ai/old_berkeley
# zz/ni4ai/old_bishop_creek
# zz/ni4ai/old_new_york
# zz/ni4ai/old_scottsdale
# zz/ni4ai/old_weld
# zz/ni4ai/old_weld2
# zz/test
# zz/test/lg_jeff01/20fe199d1014a710
# zz/test/lg_jeff01/252596eb140208d7
# zz/test/lg_jeff01/4da30861ac249f0b
# zz/test/qtree_operations
# zz/test_stream

# %% [markdown]
# ## Pretty print all collection collection stream

# %%
def describe_streams(streams: List[Stream]) -> str:
    """   
    Takes in a streamset from a collection and returns a tabulate
    formatted stringof that dataset's collection name, stream name 
    and stream units (i.e. degrees, amps, volts) and UUID.
    """
    headers = ["Index", "Collection", "Name", "Units"]
    table = []
    
    for index, stream in enumerate(streams):
        tags = stream.tags()
        table.append([
            index, stream.collection, stream.name, tags["unit"]
        ])
    
    return tabulate(table, headers=headers)

# %%
# ===================================
collection_name = 'c37'
collection_idx = 0
# ===================================


# Fetch collections from the database connection.
collections = conn.list_collections(collection_name)

# Fetch the specified collection and convert it to a StreamSet.
collection = collections[collection_idx]
streams = conn.streams_in_collection(collection)
streamset = StreamSet(streams)

# Print the StreamSet using tabulate.
stream_table = describe_streams(streamset)
print(stream_table)

stream = streamset[stream_idx]

print(stream.tags())
# Out:
#   Index  Collection           Name             Units
# -------  -------------------  ---------------  -------
#       0  c37_iowa53_6ec34c36  PH3MAG C1MagAng  Amp
#       1  c37_iowa53_430c8b35  DFREQ            ROCOF
#       2  c37_iowa51_28b62158  PH5MAG C3MagAng  Amp
#       3  c37_iowa51_243a768b  DFREQ            ROCOF
#       4  c37_iowa51_1bf98be2  PH1MAG L2MagAng  Volt
#       5  c37_iowa51_1408d2ac  TIMEQUAL         TQ
#       6  c37_iowa51_0866cb39  PH0MAG L1MagAng  Volt
#       7  c37_iowa54_70b5a315  DFREQ            ROCOF
#       8  c37_iowa54_589442fd  PH1ANG L2MagAng  degrees
#       9  c37_iowa54_3629d9f1  TIMEQUAL         TQ
#      10  c37                  PH2MAG VC1       Volt
#      11  c37                  PH1ANG VB1       degrees
#      12  c37                  PH3MAG C1MagAng  Amp
#      13  c37                  DFREQ            ROCOF
#      14  c37                  PH0MAG VA1       Volt
#      15  c37                  TIMEQUAL         TQ
#      16  c37                  PH0ANG VA1       degrees
#      17  c37                  PH1MAG VB1       Volt
#      18  c37                  FREQ             Hz
#      19  c37                  PH2ANG VC1       degrees
#      20  c37                  STAT             STAT
#      21  c37_pmu1_55104dc7    DFREQ            ROCOF
#      22  c37                  PH5ANG C3MagAng  degrees
#      23  c37                  PH4ANG C2MagAng  degrees
#      24  c37                  PH2MAG L3MagAng  Volt
#      25  c37                  PH2ANG L3MagAng  degrees
#      26  c37                  PH0MAG L1MagAng  Volt
#      27  c37_pmu1_4d658221    FREQ             Hz
#      28  c37_pmu1_78629a0f    TIMEQUAL         TQ
#      29  c37                  PH1ANG L2MagAng  degrees
#      30  c37                  PH4MAG C2MagAng  Amp
#      31  c37_pmu1_380704bb    STAT             STAT
#      32  c37                  PH3ANG C1MagAng  degrees
#      33  c37                  PH5MAG C3MagAng  Amp
#      34  c37                  PH0ANG L1MagAng  degrees
#      35  c37_iowa53_2e3108da  PH4ANG C2MagAng  degrees
#      36  c37                  PH1MAG L2MagAng  Volt
#      37  c37_iowa53_144419db  TIMEQUAL         TQ
#      38  c37_iowa53_7cd4b7a5  PH0ANG L1MagAng  degrees
#      39  c37_iowa51_1b6cffa2  PH2MAG L3MagAng  Volt
#      40  c37_iowa53_1a02070f  PH5MAG C3MagAng  Amp
#      41  c37_iowa53_6054502f  FREQ             Hz
#      42  c37_iowa53_0a2b894c  PH4MAG C2MagAng  Amp
#      43  c37_iowa53_2584c47f  PH1MAG L2MagAng  Volt
#      44  c37_iowa53_039f6f78  PH1ANG L2MagAng  degrees
#      45  c37_iowa54_43ea3b93  STAT             STAT
#      46  c37_iowa54_64f1017f  PH4MAG C2MagAng  Amp
#      47  c37_iowa53_1a714cf8  PH2ANG L3MagAng  degrees
#      48  c37_iowa53_2606cd2b  PH2MAG L3MagAng  Volt
#      49  c37_iowa54_26984b92  PH3ANG C1MagAng  degrees
#      50  c37_iowa53_4dba7b0f  PH3ANG C1MagAng  degrees
#      51  c37_iowa53_490bd268  PH5ANG C3MagAng  degrees
#      52  c37_iowa53_592e17f7  PH0MAG L1MagAng  Volt
#      53  c37_iowa53_6e661e92  STAT             STAT
#      54  c37_iowa54_162d968d  PH1MAG L2MagAng  Volt
#      55  c37_iowa54_207403de  PH4ANG C2MagAng  degrees
#      56  c37_iowa51_365a8581  PH5ANG C3MagAng  degrees
#      57  c37_iowa51_56ec3f25  PH1ANG L2MagAng  degrees
#      58  c37_iowa54_4542c292  FREQ             Hz
#      59  c37_iowa54_079143f7  PH0ANG L1MagAng  degrees
#      60  c37_iowa51_68255aaf  PH4MAG C2MagAng  Amp
#      61  c37_iowa54_2607c649  PH0MAG L1MagAng  Volt
#      62  c37_iowa51_268447a4  STAT             STAT
#      63  c37_iowa51_3c04951a  PH4ANG C2MagAng  degrees
#      64  c37_iowa54_2e4fa459  PH5ANG C3MagAng  degrees
#      65  c37_iowa54_23a62343  PH5MAG C3MagAng  Amp
#      66  c37_iowa54_4c22b029  PH3MAG C1MagAng  Amp
#      67  c37_iowa54_241b3ae4  PH2ANG L3MagAng  degrees
#      68  c37_iowa51_41f27cc6  PH2ANG L3MagAng  degrees
#      69  c37_iowa51_57e9d186  PH0ANG L1MagAng  degrees
#      70  c37_iowa51_0c697f48  FREQ             Hz
#      71  c37_iowa51_25845c95  PH3MAG C1MagAng  Amp
#      72  c37_iowa51_30b95ff1  PH3ANG C1MagAng  degrees
#      73  c37_iowa54_45a6e3ca  PH2MAG L3MagAng  Volt
# {'ingress': 'iowa51', 'distiller': '', 'name': 'DFREQ', 'unit': 'ROCOF'}

# %% [markdown]
# ## Choose a stream and print it's metadata

# %%
# ===================================
stream_idx = 3
# ===================================

stream = streamset[stream_idx]

# Print the annotations(metadata) connected to our StreamSet.
annotations = stream.annotations()
print("stream annotations: ", annotations)

print(stream.tags())
# Out:
# stream annotations:  ({'location': 'building', 'impedance': '{"source": "PMU5", "target": "PMU2", "pos_sequence": "0.489+j0.59", "neg_sequence": "0.971+j1.476"}'}, 2)
# {'name': 'C1MAG', 'unit': 'amps', 'ingress': '', 'distiller': ''}

# %% [markdown]
# ## Find the timerange of our chosen stream

# %%
def get_datetime_range(stream: Stream) -> Tuple[datetime, datetime]:
    """
    Get the earliest  and latest point in the passed stream,
    Fetching just the data point without the version and
    convert from nanoseconds to seconds
    NOTE: without knowing the timezone these might be naive calculations
    """
    first_point, _ = stream.earliest()
    first_epoch = first_point.time / 1e9 
    first_date = datetime.fromtimestamp(first_epoch)

    last_point, _ = stream.latest()
    last_epoch = last_point.time / 1e9
    last_date = datetime.fromtimestamp(last_epoch)

    return first_date, last_date

# Find the range of data (first and last timestampe) in our Stream.
first_timestamp, last_timestamp = get_datetime_range(stream)
print("First data-point in stream: ", first_timestamp)
print("Last data-point in stream: ", last_timestamp)
# Out:
# First data-point in stream:  2016-02-29 16:00:00.008333
# Last data-point in stream:  2016-05-31 16:55:48.999999

# %% [markdown]
# ## Check the entire range of the streams mean

# %%
def datetime_to_statpoints(stream: Stream, start: datetime, end: datetime, delta: timedelta) -> Tuple[StatPoint, int]:
    """
    Helper function to convert datetimes and a timedelta
    into the correct nanosecond format and return statpoints
    from a stream.windows call
    """
    start_nano = timez.to_nanoseconds(start)
    end_nano = timez.to_nanoseconds(end)
    width_ns = int(1e9 * delta.total_seconds())

    return stream.windows(start, end, width_ns)


def plot_statpoints(statpoints, aggregation: str) -> None:
    """
    Helper function to quickly plot a series of statpoints
    along the passes aggregation string   
    """
    df = statpoints_to_df(stats)
    plt.figure(figsize=(15, 5))
    plt.plot(df.index, df[aggregation], linewidth=1, color='red', linestyle='--')
    
    
def statpoints_to_df(statpoints) -> pd.DataFrame:
    """
    Converts a group of statpoint objects into a 
    dataframe with aggregation series as columns
    """
    attributes = ['min','mean','max','stddev','count','time']
    
    df = pd.DataFrame([[getattr(p, attr) for attr in attributes] for p, version in statpoints],
                          columns=attributes)
    df.index = pd.to_datetime(df['time'])
    return df

# %%
# Plot the entire range of data in our stream.
width = timedelta(minutes=10)
stats = datetime_to_statpoints(stream, first_timestamp, last_timestamp, width)
plot_statpoints(stats, 'mean')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Plot the entire range of data in our stream.
#       2 width = timedelta(minutes=10)
# ----> 3 stats = datetime_to_statpoints(stream, first_timestamp, last_timestamp, width)
#       4 plot_statpoints(stats, 'mean')
#
# Cell In[7], line 11, in datetime_to_statpoints(stream, start, end, delta)
#       8 end_nano = timez.to_nanoseconds(end)
#       9 width_ns = int(1e9 * delta.total_seconds())
# ---> 11 return stream.windows(start, end, width_ns)
#
# File ~/anaconda3/lib/python3.11/site-packages/btrdb/exceptions.py:52, in retry.<locals>.retry_func(*args, **kwargs)
#      48 @wraps(fn)
#      49 def retry_func(*args, **kwargs):
#      50     # don't retry if arg is set to False
#      51     if not kwargs.get("auto_retry"):
# ---> 52         return fn(*args, **kwargs)
#      54     total_retries = kwargs.get("retries") or MAX_RETRIES
#      55     retries = total_retries
#
# File ~/anaconda3/lib/python3.11/site-packages/btrdb/stream.py:1435, in Stream.windows(self, start, end, width, depth, version, auto_retry, retries, retry_delay, retry_backoff)
#    1433 end = to_nanoseconds(end)
#    1434 windows = self._btrdb.ep.windows(self._uuid, start, end, width, depth, version)
# -> 1435 for stat_points, version in windows:
#    1436     for point in stat_points:
#    1437         materialized.append((StatPoint.from_proto(point), version))
#
# File ~/anaconda3/lib/python3.11/site-packages/btrdb/exceptions.py:77, in consume_generator(fn, *args, **kwargs)
#      73 def consume_generator(fn, *args, **kwargs):
#      74     # when a generator is passed back to the calling function, it may encounter an error
#      75     # when trying to call next(), in that case we want to yield an Exception
#      76     try:
# ---> 77         yield from fn(*args, **kwargs)
#      78     except RpcError as e:
#      79         handle_grpc_error(e)
#
# File ~/anaconda3/lib/python3.11/site-packages/btrdb/endpoint.py:169, in Endpoint.windows(self, uu, start, end, width, depth, version)
#     159 @error_handler
#     160 def windows(self, uu, start, end, width, depth, version=0):
#     161     params = btrdb_pb2.WindowsParams(
#     162         uuid=uu.bytes,
#     163         start=start,
#    (...)
#     167         depth=depth,
#     168     )
# --> 169     for result in self.stub.Windows(params):
#     170         check_proto_stat(result.stat)
#     171         yield result.values, result.versionMajor
#
# File ~/anaconda3/lib/python3.11/site-packages/grpc/_channel.py:543, in _Rendezvous.__next__(self)
#     542 def __next__(self):
# --> 543     return self._next()
#
# File ~/anaconda3/lib/python3.11/site-packages/grpc/_channel.py:960, in _MultiThreadedRendezvous._next(self)
#     954 def _response_ready():
#     955     return self._state.response is not None or (
#     956         cygrpc.OperationType.receive_message not in self._state.due
#     957         and self._state.code is not None
#     958     )
# --> 960 _common.wait(self._state.condition.wait, _response_ready)
#     961 if self._state.response is not None:
#     962     response = self._state.response
#
# File ~/anaconda3/lib/python3.11/site-packages/grpc/_common.py:156, in wait(wait_fn, wait_complete_fn, timeout, spin_cb)
#     154 if timeout is None:
#     155     while not wait_complete_fn():
# --> 156         _wait_once(wait_fn, MAXIMUM_WAIT_TIMEOUT, spin_cb)
#     157 else:
#     158     end = time.time() + timeout
#
# File ~/anaconda3/lib/python3.11/site-packages/grpc/_common.py:116, in _wait_once(wait_fn, timeout, spin_cb)
#     111 def _wait_once(
#     112     wait_fn: Callable[..., bool],
#     113     timeout: float,
#     114     spin_cb: Optional[Callable[[], None]],
#     115 ):
# --> 116     wait_fn(timeout=timeout)
#     117     if spin_cb is not None:
#     118         spin_cb()
#
# File ~/anaconda3/lib/python3.11/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
plot_statpoints(stats, 'time')

# %%
plot_statpoints(stats, 'count')

# %% [markdown]
# ## Zoom in on a chosen point

# %%
start = datetime(2016, 4, 1)
end = start + timedelta(minutes=40)
width = timedelta(seconds=30)
stats = datetime_to_statpoints(stream, start, end, width)
plot_statpoints(stats, 'mean')

# %% [markdown]
# ## Fetch and plot raw data

# %%
def rawpoints_to_series(rawpoints: List[RawPoint]) -> pd.Series:
    """
    Takes in a list of rawpoints from a stream.values() 
    call and converts it to a pandas series.
    """
    times, values = [], []
    for rawpoint, _ in rawpoints:
        times.append(timez.ns_to_datetime(rawpoint.time))
        values.append(rawpoint.value)
        
    return pd.Series(index=times, data=values)

# %%
# Fetch and plot the data.
rawpoints = stream.values(start, end)
data = rawpoints_to_series(rawpoints)
data.plot()

# %% [markdown]
# ## Plot the voltage and current of our data

# %%
def streamset_to_dataframes(streamset: StreamSet, start: datetime, end: datetime) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Takes in a StreamSet object, using it's filter method to convert the StreamSet
    to voltage and current pandas dataframes containing RawPoints data.
    """
    voltage_stream = streamset.filter(name=re.compile("L[\d]"))
    current_stream = streamset.filter(name=re.compile("C[\d]"))

    voltage_df = voltage_stream.filter(start=start, end=end).to_dataframe()
    current_df = current_stream.filter(start=start, end=end).to_dataframe()
    
    return voltage_df, current_df

# %%
# Fetch the raw data into voltage/current dataframes.
voltage_df, current_df = streamset_to_dataframes(streamset, start, end)

# plot the data.
figsize = (15, 5)
voltage_df[voltage_df.filter(like='MAG').columns].plot(figsize=figsize, ylabel="Voltage Magnitude")
voltage_df[voltage_df.filter(like='ANG').columns].plot(figsize=figsize, ylabel="Voltage Angle")
current_df[current_df.filter(like='MAG').columns].plot(figsize=figsize, ylabel="Current Magnitude (amps)")
current_df[current_df.filter(like='ANG').columns].plot(figsize=figsize, ylabel="Current Angle")

# %%
def streamset_to_dataframes_2(streamset: StreamSet, start: datetime, end: datetime) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Takes in a StreamSet object, using it's filter method to convert the StreamSet
    to voltage and current pandas dataframes containing RawPoints data.
    """
    voltage_stream = streamset.filter(name=re.compile("L[\d]"))
    current_stream = streamset.filter(name=re.compile("C[\d]"))

    voltage_df = voltage_stream.filter(start=start, end=end).arrow_to_dataframe()
    current_df = current_stream.filter(start=start, end=end).arrow_to_dataframe()
    
#     voltage_df = voltage_df.to_pandas()
#     current_df = current_df.to_pandas()
    return voltage_df, current_df

# %%
start = datetime(2016, 4, 1)
end = start + timedelta(minutes=40)
width = timedelta(seconds=30)

voltage_df, current_df = streamset_to_dataframes_2(streamset, start, end)

voltage_df = df_to_radians(voltage_df, "L")
current_df = df_to_radians(current_df, "C")

figsize = (15, 5)
voltage_df[voltage_df.filter(like='ang_unwrap_').columns].plot(figsize=figsize, ylabel="Voltage Angle")
current_df[current_df.filter(like='ang_unwrap_').columns].plot(figsize=figsize, ylabel="Current Angle")

# %%
voltage_df.info()

# %% [markdown]
# ## Unwrap the angles to radians and calculate power

# %%
def df_to_radians(df: pd.DataFrame, unit_signifier: str) -> pd.DataFrame:
    """
    Takes in a pandas DataFrame consisting of RawPoints data and 
    unwraps each column into radians, generating new complex data columns 
    (complex_1, complex_2, complex_3), returning the modified DataFrame.
    """
    # Assuming three-phase data.
    complex_col_count = 3
    
    for i in range(1, complex_col_count + 1):
        # Unwrape the phase angle data.
        ang_series = df[f"{collection}/{unit_signifier}{i}ANG"][:]
        ang_series = np.unwrap(np.deg2rad(ang_series))
        df[f"ang_unwrap_{i}"] = ang_series

        # calculate the complex series, with angle as the imaginary units.
        mag_series = df[f"{collection}/{unit_signifier}{i}MAG"][:]
        complex_column = f"{collection}/complex_{i}"
        df[complex_column] = mag_series * np.exp(1j * ang_series)
    
    return df


def calculate_power(voltage_df: pd.DataFrame, current_df: pd.DataFrame) -> List[pd.Series]:
    """
    Performs complex power calculation on the passed voltage and current
    DataFrames, returning the calculation in a list of datapoints.
    """
    col_list = [
        "sunshine/PMU2/complex_1",
        "sunshine/PMU2/complex_2",
        "sunshine/PMU2/complex_3",
    ]
    power_list = []
    
    # multiply voltage with complex current for each complex column.
    for col in col_list:
        complex_voltage = voltage_df[col][:]
        complex_current = current_df[col][:]
        power_list.append(complex_voltage * complex_current)

    return power_list

# %%
voltage_df = df_to_radians(voltage_df, "L")
current_df = df_to_radians(current_df, "C")
power_list = calculate_power(voltage_df, current_df)

# %% [markdown]
# ## Plot the power

# %%
def plot_power(power_list: List[pd.Series]) -> None:
    """
    takes in a list of pandas Series representing the calculated 
    complex power of the voltage and current of PMU readings and 
    plots them on absolute, real and reactive power.
    """
    power_func_list = {
        np.abs: "Absolute Power - |S|",
        np.real: "Real Power - P",
        np.imag: "Reactive Power - Q",
    }
    
    # Loop over the chosen functions and plot the resulting Series.
    for func, y_label in power_func_list.items():
        plt.figure(figsize=figsize)
        
        plt.plot(func(power_list[0]), color='red', label='Phase A')
        plt.plot(func(power_list[1]), color='green', label='Phase B')
        plt.plot(func(power_list[2]), color='blue', label='Phase C')
        plt.legend()

        plt.xlabel("nanoseconds")
        plt.ylabel(y_label)

# %%
plot_power(power_list)

# %% [markdown]
# ## Zoom in on a Peak

# %%
# Take another look at the full data range for our stream.
width = timedelta(minutes=10)
stats = datetime_to_statpoints(stream, first_timestamp, last_timestamp, width)
plot_statpoints(stats, 'stddev')

# %%
# Lets look at the first half of the data.
end = first_timestamp + timedelta(days = 31)
stats = datetime_to_statpoints(stream, first_timestamp, end, width)
plot_statpoints(stats, 'stddev')

# %%
# Check the min to avoid an outage.
plot_statpoints(stats, 'min')

# %%
# Zoom in on one of the peaks from the previous plot.
start = datetime(2016, 3, 7, 13, 35)
end = start + timedelta(minutes=40)
width = timedelta(seconds = 30)
stats = datetime_to_statpoints(stream, start, end, width)
plot_statpoints(stats, 'stddev')

# %%
# Fetch voltage and current DataFrames using our StreamSet.
voltage_df, current_df = streamset_to_dataframes(streamset, start, end)

voltage_df = df_to_radians(voltage_df, "L")
current_df = df_to_radians(current_df, "C")

figsize = (15, 5)
voltage_df[voltage_df.filter(like='ang_unwrap_').columns].plot(figsize=figsize, ylabel="Voltage Angle")
current_df[current_df.filter(like='ang_unwrap_').columns].plot(figsize=figsize, ylabel="Current Angle")

# %% [markdown]
# ## Plot the voltage and current of our new data

# %%
# Fetch voltage and current DataFrames using our StreamSet.
voltage_df, current_df = streamset_to_dataframes(streamset, start, end)

# Plot the results.
voltage_df[voltage_df.filter(like='MAG').columns].plot(figsize=figsize)
voltage_df[voltage_df.filter(like='ANG').columns].plot(figsize=figsize)
current_df[current_df.filter(like='MAG').columns].plot(figsize=figsize)
current_df[current_df.filter(like='ANG').columns].plot(figsize=figsize)

# %% [markdown]
# ## Calculate and plot power

# %%
# Once again calculate the power and plot the results.
voltage_df = df_to_radians(voltage_df, "L")
current_df = df_to_radians(current_df, "C")
power_list = calculate_power(voltage_df, current_df)
plot_power(power_list)
